# %%
from skimage import io
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

img = io.imread('./images/download.jpg')

plt.imshow(img)

# %%
import pandas as pd
print("The shape of the image is: ", img.shape)
print()
print("Getting the pixels of the image")
pf = pd.DataFrame(img.flatten())
print(pf)
# Out:
# The shape of the image is:  (180, 279, 3)
#
# Getting the pixels of the image
#           0
# 0       236
# 1       236
# 2       236
# 3       236
# 4       236
# ...     ...
# 150655   41
# 150656   41
# 150657   39
# 150658   39
# 150659   39
#
# [150660 rows x 1 columns]

# %%
from skimage import color

print("Converting color space")
toBaW = color.convert_colorspace(img, 'RGB', 'HSV')
figure(1)
plt.imshow(toBaW)
anotherWay = color.rgb2ycbcr(img)
figure(2)
plt.imshow(anotherWay)
# Out:
# Converting color space
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from skimage import draw

x, y = draw.line(0, 0, 100, 100)
img[x, y] = (255, 0, 0)
plt.imshow(img)
